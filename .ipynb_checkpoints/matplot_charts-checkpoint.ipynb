# %%
import matplotlib.pyplot as plt

listado = [10, 80, 98, 30, 40]
plt.plot(listado)

# %%
plt.plot(listado, linewidth=8)

# %%
values_in_x = [100, 200, 150, 90]
values_in_y = ['CDMX', 'Puebla', 'Nuevo León', 'Oaxaca']

plt.bar(values_in_y, values_in_x)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.scatter(values_in_y, values_in_x)
